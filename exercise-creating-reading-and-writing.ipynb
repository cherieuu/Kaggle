# %% [markdown]
# **This notebook is an exercise in the [Pandas](https://www.kaggle.com/learn/pandas) course.  You can reference the tutorial at [this link](https://www.kaggle.com/residentmario/creating-reading-and-writing).**
#
# ---

# %%
import sys

# %%
sys.version
# Out:
# '3.7.9 | packaged by conda-forge | (default, Feb 13 2021, 20:03:11) \n[GCC 9.3.0]'

# %% [markdown]
# # Introduction
#
# The first step in most data analytics projects is reading the data file. In this exercise, you'll create Series and DataFrame objects, both by hand and by reading data files.
#
# Run the code cell below to load libraries you will need (including code to check your answers).

# %%
import pandas as pd
pd.set_option('max_rows', 5)
from learntools.core import binder; binder.bind(globals()) #learntools는 아래서 쓰일 솔류션같은것을 지원하는 것이다.
from learntools.pandas.creating_reading_and_writing import *
print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
#
# In the cell below, create a DataFrame `fruits` that looks like this:
#
# ![](https://i.imgur.com/Ax3pp2A.png)

# %%
fruits=pd.DataFrame([[30,20]], columns=['Apples', 'Bananas'])

# %%
fruits
# Out:
#    Apples  Bananas
# 0      30       20

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruits.
fruits = ____

# Check your answer
q1.check()
fruits
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `fruits`

# %%
q1.hint()
# Out:
# Hint: Use the `pd.DataFrame` constructor to create the DataFrame.

# %%
q1.solution()
# Out:
# Solution:
# ```python
# fruits = pd.DataFrame([[30, 21]], columns=['Apples', 'Bananas'])
# ```

# %%
#q1.hint()
#q1.solution()

# %% [markdown]
# ## 2.
#
# Create a dataframe `fruit_sales` that matches the diagram below:
#
# ![](https://i.imgur.com/CHPn7ZF.png)

# %%
fruits=pd.DataFrame([[35,21],[41,34]], columns=['Apples', 'Bananas'], index=['2017 Sales', '2018 Sales'])

# %%
fruits
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
fruits['Apples'][0]
# Out:
# 35

# %%
fruits['Bananas']
# Out:
# 2017 Sales    21
# 2018 Sales    34
# Name: Bananas, dtype: int64

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruit_sales.
fruit_sales = ____

# Check your answer
q2.check()
fruit_sales
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `fruit_sales`

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ## 3.
#
# Create a variable `ingredients` with a Series that looks like:
#
# ```
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object
# ```

# %%
ingre_dict = {'Flour': '4 cups', 'Milk':'1 cup', 'Eggs':'2 large','Spam':'1 can'}

# %%
ingre_dict
# Out:
# {'Flour': '4 cups', 'Milk': '1 cup', 'Eggs': '2 large', 'Spam': '1 can'}

# %%
ingredients = pd.Series(['4 cups','1 cup','2 large','1 can'], index = ['Flour','Milk','Eggs','Spam'], name = 'Dinner')

# %%
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
ingredients = pd.Series(['4 cups','1 cup','2 large','1 can'], index = ['Flour','Milk','Eggs','Spam'], name = 'Dinner')

# Check your answer
q3.check()
ingredients
# Out:
# Correct
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
#q3.hint()
q3.solution()
# Out:
# Solution:
# ```python
# quantities = ['4 cups', '1 cup', '2 large', '1 can']
# items = ['Flour', 'Milk', 'Eggs', 'Spam']
# recipe = pd.Series(quantities, index=items, name='Dinner')
# ```

# %%
quantities = ['4 cups', '1 cup', '2 large', '1 can']

# %%
items = ['Flour', 'Milk', 'Eggs', 'Spam']

# %%
recipe = pd.Series(quantities, index=items, name='Dinner')

# %%
recipe
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %% [markdown]
# ## 4.
#
# Read the following csv dataset of wine reviews into a DataFrame called `reviews`:
#
# ![](https://i.imgur.com/74RCZtU.png)
#
# The filepath to the csv file is `../input/wine-reviews/winemag-data_first150k.csv`. The first few lines look like:
#
# ```
# ,country,description,designation,points,price,province,region_1,region_2,variety,winery
# 0,US,"This tremendous 100% varietal wine[...]",Martha's Vineyard,96,235.0,California,Napa Valley,Napa,Cabernet Sauvignon,Heitz
# 1,Spain,"Ripe aromas of fig, blackberry and[...]",Carodorum Selección Especial Reserva,96,110.0,Northern Spain,Toro,,Tinta de Toro,Bodega Carmen Rodríguez
# ```

# %%
# %cd ..
# Out:
# /kaggle

# %%
# %cd input
# Out:
# /kaggle/input

# %%
# %ls -l
# Out:
# total 0
# drwxr-xr-x 2 nobody nogroup 0 Nov 18  2020 188-million-us-wildfires/
# drwxr-xr-x 2 nobody nogroup 0 Nov 18  2020 chess/
# drwxr-xr-x 2 nobody nogroup 0 Nov 18  2020 kepler-exoplanet-search-results/
# drwxr-xr-x 2 nobody nogroup 0 Nov 18  2020 pitchfork-data/
# drwxr-xr-x 2 nobody nogroup 0 Nov 18  2020 powerlifting-database/
# drwxr-xr-x 8 nobody nogroup 0 Nov 18  2020 publicassistance/
# drwxr-xr-x 2 nobody nogroup 0 Nov 18  2020 ramen-ratings/
# drwxr-xr-x 3 nobody nogroup 0 Nov 18  2020 things-on-reddit/
# drwxr-xr-x 2 nobody nogroup 0 Nov 17  2020 wine-reviews/
# drwxr-xr-x 2 nobody nogroup 0 Nov 17  2020 youtube-new/

# %%
# %cd wine-reviews
# Out:
# /kaggle/input/wine-reviews

# %%
# %ls -l
# Out:
# total 8
# ---------- 1 root root 263 Jun  7 04:15 __notebook_source__.ipynb
# -rw-r--r-- 1 root root  23 Jun  7 05:23 animal.csv

# %%
# !ls -l
# Out:
# total 177716
# -rw-r--r-- 1 nobody nogroup 52908706 Nov 17  2020 winemag-data-130k-v2.csv
# -rw-r--r-- 1 nobody nogroup 79279294 Nov 17  2020 winemag-data-130k-v2.json
# -rw-r--r-- 1 nobody nogroup 49784334 Nov 17  2020 winemag-data_first150k.csv

# %%
# !pwd
# Out:
# /kaggle/input/wine-reviews

# %%
reviews = pd.read_csv('/kaggle/input/wine-reviews/winemag-data_first150k.csv', index_col=0)

# Check your answer
q4.check()
# reviews
# Out:
# Correct

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# ...            ...       ...
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# ...                                                   ...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# ...

# %%
#q4.hint()
#q4.solution()
# Out:
# Solution:
# ```python
# reviews = pd.read_csv('../input/wine-reviews/winemag-data_first150k.csv', index_col=0)
# ```

# %% [markdown]
# ## 5.
#
# Run the cell below to create and display a DataFrame called `animals`:

# %%
import pandas as pd

# %%
# %cd kaggle
# Out:
# /kaggle

# %%
# %ls -l
# Out:
# total 12
# drwxr-xr-x 12 root root 4096 Jun  7 04:15 input/
# drwxr-xr-x  3 root root 4096 Jun  7 04:15 lib/
# drwxr-xr-x  2 root root 4096 Jun  7 05:23 working/

# %%
# %cd working
# Out:
# /kaggle/working

# %%
# !pwd
# Out:
# /kaggle/working

# %%
cows_and_goats = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
cows_and_goats
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %%
cows_and_goats['Cows'][0]
# Out:
# 12

# %%
cows_and_goats['Goats'][1]
# Out:
# 19

# %%
cows_and_goats[:1]
# Out:
#         Cows  Goats
# Year 1    12     22

# %%
cows_and_goats[0:2]
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %%
cows_and_goats.to_csv('cows_and_goats.csv') # cows_and_goats 데이터프레임 저장하는 것

# %%
pd1=pd.read_csv('./cows_and_goats.csv', index_col=0) # 저장한 cows_and_goats.csv 데이터프레임을 읽는 것

# %% [markdown]
# In the cell below, write code to save this DataFrame to disk as a csv file with the name `cows_and_goats.csv`.

# %%
pd1
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %%
# Your code goes here

# Check your answer
q5.check()
# Out:
# Correct

# %%
#q5.hint()
#q5.solution()

# %% [markdown]
# # Keep going
#
# Move on to learn about **[indexing, selecting and assigning](https://www.kaggle.com/residentmario/indexing-selecting-assigning)**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161299) to chat with other Learners.*
